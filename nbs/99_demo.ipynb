# %%
from conf.default import get_cfg_defaults
from Noise2Model.trainer import get_trainer_class

# %%
# !gpustat
# Out:
# merlin                      Fri Jun 14 13:09:32 2024  525.147.05
# [0] NVIDIA GeForce RTX 4090 | 48°C,   0 % |   910 / 24564 MB |
# [1] NVIDIA GeForce RTX 4090 | 47°C,  10 % |   677 / 24564 MB |

# %%
from torch.cuda import is_available
print(is_available())
# Out:
# True

# %%
device = '0'

config = get_cfg_defaults()
config.merge_from_file('../conf/NMFlowGAN_NoiseModeler2.yaml')

# %%
[int(i) for i in device.split(',')]
# Out:
# [0]

# %%
# intialize trainer
trainer = get_trainer_class(config.BASE.trainer)(config)
trainer.set_device(device)
trainer.train()
# Out:
# Prepare training dataloader...
# 100%|██████████| 50/50 [00:07<00:00,  6.30it/s]
# Done!
# Prepare validation dataloader...
# 100%|██████████| 50/50 [00:07<00:00,  6.32it/s]
# Done!
# Start >>>
# .BASE.model: nmflowgan
# .BASE.trainer: NoiseFlowGANTrainer
# .BASE.seed: 2016309
# .BASE.resume: False
# .BASE.pretrained: None
# .MODEL.input_type: ['noisy', 'clean', 'kwargs']
# .MODEL.test_input_type: ['noisy', 'clean', 'kwargs']
# .MODEL.DNCNN.channels: 1
# .MODEL.DNCNN.num_of_layers: 18
# .MODEL.DNCNN.features: 64
# .MODEL.UNET.in_channels: 3
# .MODEL.UNET.n_classes: 3
# .MODEL.UNET.depth: 5
# .MODEL.UNET.wf: 6
# .MODEL.UNET.padding: True
# .MODEL.UNET.batch_norm: False
# .MODEL.UNET.up_mode: upconv
# .MODEL.UNET.residual: True
# .MODEL.UNET.drop_p: 0.0
# .MODEL.NMFLOWGAN_CRITIC.in_ch: 6
# .MODEL.NMFLOWGAN_CRITIC.nc: 64
# .MODEL.NMFLOWGAN_CRITIC.num_bits: 8
# .MODEL.NMFLOW.in_ch: 3
# .MODEL.NMFLOW.num_bits: 8
# .MODEL.NMFLOW.pre_arch: UD
# .MODEL.NMFLOW.arch: NE|SAL|SDL|CL2|SAL|SDL|CL2
# .MODEL.NMFLOW.ch_exp_coef: 1
# .MODEL.NMFLOW.width_exp_coef: 1.334
# .MODEL.NMFLOW.conv_net_feats: 16
# .MODEL.DNCNNFLOWGAN.pretrained_path:
# .MODEL.DNCNNFLOWGAN.num_bits: 0
# .LOG.session_name: nmflowgan2
# .LOG.interval_iter: 10
# .DATA.train_dataset: SIDD_HDF
# .DATA.validation_dataset: SIDD_HDF
# .DATA.test_dataset: SIDD_HDF
# .DATA.train_dataset_path: ../_data/HDF5_confocal_s96_o08/noise_gen/train
# .DATA.validation_dataset_path: ../_data/HDF5_confocal_s96_o08/noise_gen/test
# .DATA.test_dataset_path: ../_data/HDF5_confocal_s64_o08/noise_gen/test
# .DATA.output_path: None
# .DATA.threads: 0
# .DATA.batch_size: 2
# .DATA.TRAIN_DATALOADER.add_noise: None
# .DATA.TRAIN_DATALOADER.crop_size: None
# .DATA.TRAIN_DATALOADER.aug: ['hflip', 'rot']
# .DATA.TRAIN_DATALOADER.n_repeat: 1
# .DATA.TRAIN_DATALOADER.n_data: None
# .DATA.TRAIN_DATALOADER.step: 1
# .DATA.TRAIN_DATALOADER.scale: None
# .DATA.TRAIN_DATALOADER.path: ../_data/HDF5_confocal_s96_o08/noise_gen/train
# .DATA.VALIDATION_DATALOADER.add_noise: None
# .DATA.VALIDATION_DATALOADER.crop_size: None
# .DATA.VALIDATION_DATALOADER.aug: None
# .DATA.VALIDATION_DATALOADER.n_repeat: 1
# .DATA.VALIDATION_DATALOADER.n_data: None
# .DATA.VALIDATION_DATALOADER.step: 100
# .DATA.VALIDATION_DATALOADER.scale: None
# .DATA.VALIDATION_DATALOADER.path: ../_data/HDF5_confocal_s96_o08/noise_gen/test
# .DATA.TEST_DATALOADER.add_noise: None
# .DATA.TEST_DATALOADER.crop_size: None
# .DATA.TEST_DATALOADER.aug: None
# .DATA.TEST_DATALOADER.n_repeat: 1
# .DATA.TEST_DATALOADER.n_data: None
# .DATA.TEST_DATALOADER.step: 1
# .DATA.TEST_DATALOADER.scale: None
# .TRAIN.init_lr: 0.0001
# .TRAIN.warmup: False
# .TRAIN.warmup_iters: 200
# .TRAIN.loss: 1.0*NLLLoss+0.5*GANLoss
# .TRAIN.max_epochs: 40
# .TRAIN.tmp_info: ['std_z', 'real_sub_fake']
# .TRAIN.LOSS.C2N.gp_lambda: 0.0
# .TRAIN.LOSS.C2N.w_stb: 0.0
# .TRAIN.NOISE_GENERATOR_TRAINER.generator_iter_step: 5
# .TRAIN.NOISE_GENERATOR_TRAINER.critic_noise: True
# .OPTIMIZER.type: Adam
# .OPTIMIZER.ADAM.betas: [0.9, 0.999]
# .SCHEDULER.type: step
# .SCHEDULER.STEP.step_size: 10
# .SCHEDULER.STEP.gamma: 0.5
# .CKPT.save: True
# .CKPT.start_epoch: 1
# .CKPT.interval_epoch: 1
# .VALIDATION.save_image: True
# .VALIDATION.start_epoch: 1
# .VALIDATION.interval_epoch: 1
# .VALIDATION.add_con: 0.5
# .VALIDATION.floor: True
# .VALIDATION.scale: None
# .VALIDATION.using_bits: 8
# .TEST.ckpt_epoch: -1
# .TEST.test_img: None
# .TEST.test_dir: None
# .TEST.self_en: None
# .TEST.add_con: 0.5
# .TEST.save_image: True
# .TEST.floor: True
# .TEST.crop: False
# .TEST.scale: None
# .TEST.using_bits: 8
# .TEST.proc: False
# .TEST.imread: rgb
# .TEST.save_dir: ./
# .TEST.save_ext: png
# .TEST.TEST_DIR.postfix:
# .TEST.TEST_DIR.save_original_img: False
# .TEST.TEST_DIR.no_input_frames: 1
# .TEST.CROP.size: 256
# .TEST.CROP.overlap: 128
# .TEST.PROC.bias: 0
# .TEST.PROC.blending: 1.0
# camera :  tensor([[1.],
#         [1.]], device='cuda:0')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 4
#       2 trainer = get_trainer_class(config.BASE.trainer)(config)
#       3 trainer.set_device(device)
# ----> 4 trainer.train()
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:94, in BaseTrainer.train(self)
#      92 for self.epoch in range(self.epoch, self.max_epoch+1):
#      93     self._before_epoch()
# ---> 94     self._run_epoch()
#      95     self._after_epoch()
#      97 self._after_train()
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:121, in BaseTrainer._run_epoch(self)
#     119 for self.iter in range(1, self.max_iter+1):
#     120     self._before_step()
# --> 121     self._run_step()
#     122     self._after_step()
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:1042, in NoiseFlowGANTrainer._run_step(self)
#    1039 # zero grad
#    1040 self.optimizer[mode].zero_grad(set_to_none=True)
# -> 1042 loss, tmp_info = self._forward_fn(self.model, self.loss, data, mode)
#    1043 losses.update({f'{mode}_'+key: loss[key].mean() for key in loss})
#    1044 tmp_infos.update({f'{mode}_'+key: tmp_info[key].mean() for key in tmp_info})
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:810, in NoiseFlowGANTrainer._forward_fn(self, module, loss, data, mode)
#     807 assert 'clean' in data['dataset'] and 'noisy' in data['dataset']
#     809 input_data = [data['dataset'][arg] for arg in self.config.MODEL.input_type] # noisy, clean, kwargs..
# --> 810 z, ldj, noisy, px_noisy = module['generator'](*input_data)
#     811 model_output = {'z':z, 'ldj':ldj, 'noisy':noisy, 'px_noisy': px_noisy}
#     813 model_output['fake'] = model_output['noisy']
#
# File ~/miniconda3/envs/n2m/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/n2m/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Code/Noise2Model/Noise2Model/models.py:149, in NMFlow.forward(self, noisy, clean, kwargs)
#     146     objectives += ldj
#     148 for bijector in self.bijectors:
# --> 149     x, ldj = bijector._forward_and_log_det_jacobian(x, **kwargs)
#     150     objectives += ldj
#     151 return x, objectives
#
# File ~/Code/Noise2Model/Noise2Model/layers.py:643, in StructureAwareConditionalLinearLayer._forward_and_log_det_jacobian(self, x, **kwargs)
#     631 def _forward_and_log_det_jacobian(self, x, **kwargs):
#     632     """
#     633     Applies the forward transformation to the input tensor x and computes the log determinant of the Jacobian.
#     634
#    (...)
#     641         tensor: The log determinant of the Jacobian of the transformation.
#     642     """
# --> 643     embedding = self._get_embeddings(x, **kwargs)
#     645     log_scale = embedding[:, :self.in_ch, ...]
#     646     bias = embedding[:, self.in_ch:, ...]
#
# File ~/Code/Noise2Model/Noise2Model/layers.py:605, in StructureAwareConditionalLinearLayer._get_embeddings(self, x, **kwargs)
#     602 batch_size = x.shape[0]
#     604 # Generate embeddings using the meta encoder
# --> 605 meta_embedding = self.meta_encoder(self._computeOneHot(batch_size,**kwargs))
#     606 meta_embedding = meta_embedding.reshape((-1, self.in_ch * 2, 1, 1))
#     608 # Generate structure embeddings and combine with meta embeddings
#
# File ~/Code/Noise2Model/Noise2Model/layers.py:589, in StructureAwareConditionalLinearLayer._computeOneHot(self, b, **kwargs)
#     588 def _computeOneHot(self, b, **kwargs):
# --> 589     return compute_one_hot(self.codes, device=self.device)(b, **kwargs)
#
# File ~/Code/Noise2Model/Noise2Model/utils.py:68, in compute_one_hot.__call__(self, b, **kwargs)
#      67 def __call__(self, b, **kwargs):
# ---> 68     return self._compute_one_hot(b, **kwargs)
#
# File ~/Code/Noise2Model/Noise2Model/utils.py:63, in compute_one_hot._compute_one_hot(self, b, **kwargs)
#      61     idx_one_hot = F.one_hot(idx.to(torch.int64), num_classes=value.shape[0]).to(torch.float32)
#      62     print(key, ': ', idx_one_hot)
# ---> 63     embedding = torch.cat((embedding, idx_one_hot), dim=1)
#      65 return embedding
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cpu and cuda:0! (when checking argument for argument tensors in method wrapper_CUDA_cat)
