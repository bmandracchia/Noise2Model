# %% [raw]
# ---
# description: Utility functions
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ### Compute attribute index

# %%
#| echo: false
#| output: asis
show_doc(ComputeIndex)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L32){target="_blank" style="float:right; font-size:smaller"}
#
# ### ComputeIndex
#
# >      ComputeIndex (codes)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
device = 'cuda:0'
codes = {
        'exposure-time': torch.tensor([10, 50, 100], dtype=torch.float32, device=device),
        'optical-setup': torch.tensor([0, 1], dtype=torch.float32).to(device),
        'camera': torch.tensor([0, 1], dtype=torch.float32).to(device)
    }
kwargs = {
        'exposure-time': torch.tensor([100], dtype=torch.float32).to(device),
        'optical-setup': torch.tensor([1], dtype=torch.float32).to(device),
        'camera': torch.tensor([0], dtype=torch.float32).to(device)
    }

fn = ComputeIndex(codes)

print('index: ', fn(1, **kwargs))
# Out:
# index:  tensor([10.], device='cuda:0')

# %% [markdown]
# ### One-Hot encoding

# %%
#| echo: false
#| output: asis
show_doc(ComputeOneHot)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L55){target="_blank" style="float:right; font-size:smaller"}
#
# ### ComputeOneHot
#
# >      ComputeOneHot (codes)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
fn1hot = ComputeOneHot(codes)

print('one hot encoding: ', fn1hot(1, **kwargs))
# Out:
# one hot encoding:  tensor([[0., 0., 1., 0., 1., 1., 0.]], device='cuda:0')

# %% [markdown]
# ### Normal Distribution

# %%
#| echo: false
#| output: asis
show_doc(sum_except_batch)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L94){target="_blank" style="float:right; font-size:smaller"}
#
# ### sum_except_batch
#
# >      sum_except_batch (x, num_dims=1)
#
# Sums all dimensions except the first.
# Args:
#     x: Tensor, shape (batch_size, ...)
#     num_dims: int, number of batch dims (default=1)
# Returns:
#     x_sum: Tensor, shape (batch_size,)

# %%
#| echo: false
#| output: asis
show_doc(StandardNormal)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L77){target="_blank" style="float:right; font-size:smaller"}
#
# ### StandardNormal
#
# >      StandardNormal ()
#
# A multivariate Normal with zero mean and unit covariance.

# %% [markdown]
# ## Base Utilities

# %%
#| echo: false
#| output: asis
show_doc(attributesFromDict)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L106){target="_blank" style="float:right; font-size:smaller"}
#
# ### attributesFromDict
#
# >      attributesFromDict (d)
#
# The `attributesFromDict` function simplifies the conversion of dictionary keys and values into object attributes, allowing dynamic attribute creation for configuration objects. This utility is handy for initializing model or dataset configurations directly from dictionaries, improving code readability and maintainability.

# %%
#| echo: false
#| output: asis
show_doc(np2tensor)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L115){target="_blank" style="float:right; font-size:smaller"}
#
# ### np2tensor
#
# >      np2tensor (n:<built-infunctionarray>)
#
# transform numpy array (image) to torch Tensor
# BGR -> RGB
# (h,w,c) -> (c,h,w)

# %%
a = np.random.rand(4, 4)
assert np2tensor(a).type() == 'torch.DoubleTensor'

# %%
a = np.random.randint(0, high=255, size=(4,4))
assert np2tensor(a).type() == 'torch.LongTensor'

# %%
#| echo: false
#| output: asis
show_doc(np2tensor_multi)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L134){target="_blank" style="float:right; font-size:smaller"}
#
# ### np2tensor_multi
#
# >      np2tensor_multi (n:<built-infunctionarray>)

# %%
#| echo: false
#| output: asis
show_doc(tensor2np)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L146){target="_blank" style="float:right; font-size:smaller"}
#
# ### tensor2np
#
# >      tensor2np (t:torch.Tensor)
#
# transform torch Tensor to numpy having opencv image form.
# RGB -> BGR
# (c,h,w) -> (h,w,c)

# %%
#| echo: false
#| output: asis
show_doc(imread_tensor)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L171){target="_blank" style="float:right; font-size:smaller"}
#
# ### imread_tensor
#
# >      imread_tensor (name='test')

# %%
#| echo: false
#| output: asis
show_doc(imwrite_tensor)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L168){target="_blank" style="float:right; font-size:smaller"}
#
# ### imwrite_tensor
#
# >      imwrite_tensor (t, name='test.png')

# %%
#| echo: false
#| output: asis
show_doc(rot_hflip_img)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L176){target="_blank" style="float:right; font-size:smaller"}
#
# ### rot_hflip_img
#
# >      rot_hflip_img (img:torch.Tensor, rot_times:int=0, hflip:int=0)
#
# rotate '90 x times degree' & horizontal flip image
# (shape of img: b,c,h,w or c,h,w)

# %%
#| echo: false
#| output: asis
show_doc(psnr)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L213){target="_blank" style="float:right; font-size:smaller"}
#
# ### psnr
#
# >      psnr (x, y, mask=None, max_val=1.0)

# %%
#| echo: false
#| output: asis
show_doc(ssim)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L223){target="_blank" style="float:right; font-size:smaller"}
#
# ### ssim
#
# >      ssim (img1:torch.Tensor, img2:torch.Tensor, data_range)
#
# image value range : [0 - data_range]
# clipping for model output

# %%
#| echo: false
#| output: asis
show_doc(AverageMeter)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L241){target="_blank" style="float:right; font-size:smaller"}
#
# ### AverageMeter
#
# >      AverageMeter ()
#
# Computes and stores the average and current value.

# %%
#| echo: false
#| output: asis
show_doc(setup_determinism)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L263){target="_blank" style="float:right; font-size:smaller"}
#
# ### setup_determinism
#
# >      setup_determinism (seed)

# %%
#| echo: false
#| output: asis
show_doc(get_gaussian_2d_filter)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L273){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_gaussian_2d_filter
#
# >      get_gaussian_2d_filter (window_size, sigma, channel=1,
# >                              device=device(type='cpu'))
#
# return 2d gaussian filter window as tensor form
# Arg:
#     window_size : filter window size
#     sigma : standard deviation

# %%
#| echo: false
#| output: asis
show_doc(get_mean_2d_filter)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L291){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_mean_2d_filter
#
# >      get_mean_2d_filter (window_size, channel=1, device=device(type='cpu'))
#
# return 2d mean filter as tensor form
# Args:
#     window_size : filter window size

# %%
#| echo: false
#| output: asis
show_doc(mean_conv2d)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L303){target="_blank" style="float:right; font-size:smaller"}
#
# ### mean_conv2d
#
# >      mean_conv2d (x, window_size=None, window=None, filter_type='gau',
# >                   sigma=None, keep_sigma=False, padd=True)
#
# color channel-wise 2d mean or gaussian convolution
# Args:
#     x : input image
#     window_size : filter window size
#     filter_type(opt) : 'gau' or 'mean'
#     sigma : standard deviation of gaussian filter

# %%
#| echo: false
#| output: asis
show_doc(get_file_name_from_path)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L342){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_file_name_from_path
#
# >      get_file_name_from_path (path)

# %%
#| echo: false
#| output: asis
show_doc(get_histogram)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L358){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_histogram
#
# >      get_histogram (data, bin_edges=None, cnt_regr=1)

# %%
#| echo: false
#| output: asis
show_doc(kl_div_forward)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L366){target="_blank" style="float:right; font-size:smaller"}
#
# ### kl_div_forward
#
# >      kl_div_forward (p, q)

# %%
#| echo: false
#| output: asis
show_doc(kl_div_3_data)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L376){target="_blank" style="float:right; font-size:smaller"}
#
# ### kl_div_3_data
#
# >      kl_div_3_data (real_noise, gen_noise, bin_edges=None, left_edge=0.0,
# >                     right_edge=1.0)

# %%
#| echo: false
#| output: asis
show_doc(load_numpy_from_raw)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L399){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_numpy_from_raw
#
# >      load_numpy_from_raw (path, dtype='float32')

# %%
#| echo: false
#| output: asis
show_doc(make_predefiend_1d_to_2d)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L406){target="_blank" style="float:right; font-size:smaller"}
#
# ### make_predefiend_1d_to_2d
#
# >      make_predefiend_1d_to_2d (arr)

# %%
#| echo: false
#| output: asis
show_doc(save_img)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L418){target="_blank" style="float:right; font-size:smaller"}
#
# ### save_img
#
# >      save_img (dir_name, file_name, img)

# %% [markdown]
# ## File Manager

# %%
#| echo: false
#| output: asis
show_doc(FileManager)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L438){target="_blank" style="float:right; font-size:smaller"}
#
# ### FileManager
#
# >      FileManager (session_name, output_path=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ## Logging

# %% [markdown]
# ### Progress Message

# %%
#| echo: false
#| output: asis
show_doc(ProgressMsg)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L478){target="_blank" style="float:right; font-size:smaller"}
#
# ### ProgressMsg
#
# >      ProgressMsg (max_iter, min_time_interval=0.1)
#
# Args:
#     max_iter : (max_epoch, max_data_length, ...)
#     min_time_interval (second)

# %%
logging.basicConfig(
        format='%(message)s',
        level=logging.INFO,
        handlers=[logging.StreamHandler()]
        )

min_time = 1
max_iter = 1

pp = ProgressMsg((max_iter,min_time))
ss = (0, 0)

pp.start(ss)

for i in range(0, max_iter):
    for j in range(max_iter):
        for k in range(max_iter):
            time.sleep(0.5)
            pp.print_prog_msg((i, j))
        logging.info('ttt')
# Out:
# ttt
# >>> progress : 0.00%, elapsed: 0:00:00, remaining: INF, total: INF

# %% [markdown]
# ### Logger

# %%
#| echo: false
#| output: asis
show_doc(bcolors)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L636){target="_blank" style="float:right; font-size:smaller"}
#
# ### bcolors
#
# >      bcolors ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(Logger)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/utils.py#L560){target="_blank" style="float:right; font-size:smaller"}
#
# ### Logger
#
# >      Logger (max_iter:tuple=None, log_dir:str=None, log_file_option:str='w',
# >              log_lvl:str='note', log_file_lvl:str='info',
# >              log_include_time:bool=True)
#
# Args:
#     session_name (str)
#     max_iter (tuple) : max iteration for progress
#     log_dir (str) : if None, no file out for logging
#     log_file_option (str) : 'w' or 'a'
#     log_lvl (str) : 'debug' < 'note' < 'info' < 'highlight' < 'val'
#     log_include_time (bool)
