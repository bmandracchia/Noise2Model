# %%
from conf.default import get_cfg_defaults
from Noise2Model.trainer import get_trainer_class

# %%
device = '0'

config = get_cfg_defaults()
config.merge_from_file('../conf/NMFlowGAN_NoiseModeler2.yaml')

# %%
# intialize trainer
trainer = get_trainer_class(config.BASE.trainer)(config)
trainer.set_device(device)
trainer.train()
# Out:
# Prepare training dataloader...
# 100%|██████████| 50/50 [00:28<00:00,  1.73it/s]
# Done!
# Prepare validation dataloader...
# 100%|██████████| 50/50 [00:29<00:00,  1.72it/s]
# Done!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 4
#       2 trainer = get_trainer_class(config.BASE.trainer)(config)
#       3 trainer.set_device(device)
# ----> 4 trainer.train()
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:85, in BaseTrainer.train(self)
#      83 def train(self):
#      84     # initializing
# ---> 85     self._before_train()
#      87     # warmup
#      88     if self.epoch == 1 and self.config.TRAIN.warmup:
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:228, in BaseTrainer._before_train(self)
#     225 max_len = self.train_dataloader['dataset'].dataset.__len__() # base number of iteration works for dataset named 'dataset'
#     226 self.max_iter = math.ceil(max_len / self.config.DATA.batch_size)
# --> 228 self._set_loss()
#     229 self.loss_dict = {'count':0}
#     230 self.tmp_info = {}
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:188, in BaseTrainer._set_loss(self)
#     187 def _set_loss(self):
# --> 188     self.loss = Loss(self.config.TRAIN.loss, self.config.TRAIN.tmp_info)
#
# File ~/Code/Noise2Model/Noise2Model/loss.py:47, in Loss.__init__(self, loss_string, tmp_info)
#      42         self.loss_list.append({ 'name': name,
#      43                                 'weight': float(weight),
#      44                                 'func': loss_class_dict[name](),
#      45                                 'ratio': ratio})
#      46     else:
# ---> 47         raise RuntimeError('undefined loss term: {}'.format(name))
#      49 # parse temporal information string
#      50 self.tmp_info_list = []
#
# RuntimeError: undefined loss term: ganloss
