# %% [raw]
# ---
# description: Train functions
# output-file: trainer.html
# title: Trainer
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
from torch import randn as torch_randn

# %%
#| echo: false
#| output: asis
show_doc(get_trainer_class)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/trainer.py#L38){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_trainer_class
#
# >      get_trainer_class (trainer_name:str)

# %%
#| echo: false
#| output: asis
show_doc(regist_trainer)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/trainer.py#L31){target="_blank" style="float:right; font-size:smaller"}
#
# ### regist_trainer
#
# >      regist_trainer (trainer)

# %% [markdown]
# ## Base Trainer

# %%
#| echo: false
#| output: asis
show_doc(BaseTrainer)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/trainer.py#L43){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseTrainer
#
# >      BaseTrainer (config)
#
# Base trainer class to implement other trainer classes.
# below function should be implemented in each of trainer class.

# %% [markdown]
# ## NoiseFlowGAN Trainer

# %%
#| echo: false
#| output: asis
show_doc(NoiseFlowGANTrainer)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/trainer.py#L771){target="_blank" style="float:right; font-size:smaller"}
#
# ### NoiseFlowGANTrainer
#
# >      NoiseFlowGANTrainer (config)
#
# Base trainer class to implement other trainer classes.
# below function should be implemented in each of trainer class.

# %% [markdown]
# ## Supervised Denoising Trainer

# %%
#| echo: false
#| output: asis
show_doc(SLDenoisingTrainer)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/trainer.py#L1071){target="_blank" style="float:right; font-size:smaller"}
#
# ### SLDenoisingTrainer
#
# >      SLDenoisingTrainer (config)
#
# Base trainer class to implement other trainer classes.
# below function should be implemented in each of trainer class.
