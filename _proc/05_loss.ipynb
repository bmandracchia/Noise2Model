# %% [raw]
# ---
# description: Loss functions
# output-file: loss.html
# title: Loss
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
from torch import randn as torch_randn
from fastai.vision.all import test_eq

# %%
#| echo: false
#| output: asis
show_doc(get_loss_class)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/loss.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_loss_class
#
# >      get_loss_class (loss_name:str)

# %%
#| echo: false
#| output: asis
show_doc(regist_loss)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/loss.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### regist_loss
#
# >      regist_loss (loss)

# %% [markdown]
# ## Base functions

# %%
#| echo: false
#| output: asis
show_doc(Loss)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/loss.py#L30){target="_blank" style="float:right; font-size:smaller"}
#
# ### Loss
#
# >      Loss (loss_string, tmp_info=[])
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
#     As per the example above, an ``__init__()`` call to the parent class
#     must be made before assignment on the child.
#
# :ivar training: Boolean represents whether this module is in training or
#                 evaluation mode.
# :vartype training: bool

# %%
#| echo: false
#| output: asis
show_doc(L2Loss)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/loss.py#L120){target="_blank" style="float:right; font-size:smaller"}
#
# ### L2Loss
#
# >      L2Loss (*args, **kwargs)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
#     As per the example above, an ``__init__()`` call to the parent class
#     must be made before assignment on the child.
#
# :ivar training: Boolean represents whether this module is in training or
#                 evaluation mode.
# :vartype training: bool

# %%
#| echo: false
#| output: asis
show_doc(L1Loss)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/loss.py#L112){target="_blank" style="float:right; font-size:smaller"}
#
# ### L1Loss
#
# >      L1Loss (*args, **kwargs)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
#     As per the example above, an ``__init__()`` call to the parent class
#     must be made before assignment on the child.
#
# :ivar training: Boolean represents whether this module is in training or
#                 evaluation mode.
# :vartype training: bool

# %% [markdown]
# ## NLL

# %%
#| echo: false
#| output: asis
show_doc(std_z)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/loss.py#L142){target="_blank" style="float:right; font-size:smaller"}
#
# ### std_z
#
# >      std_z ()
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
#     As per the example above, an ``__init__()`` call to the parent class
#     must be made before assignment on the child.
#
# :ivar training: Boolean represents whether this module is in training or
#                 evaluation mode.
# :vartype training: bool

# %%
#| echo: false
#| output: asis
show_doc(NLLLoss)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/loss.py#L128){target="_blank" style="float:right; font-size:smaller"}
#
# ### NLLLoss
#
# >      NLLLoss ()
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
#     As per the example above, an ``__init__()`` call to the parent class
#     must be made before assignment on the child.
#
# :ivar training: Boolean represents whether this module is in training or
#                 evaluation mode.
# :vartype training: bool

# %% [markdown]
# ## GAN

# %%
#| echo: false
#| output: asis
show_doc(GANLoss)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/loss.py#L155){target="_blank" style="float:right; font-size:smaller"}
#
# ### GANLoss
#
# >      GANLoss (lambda_gp=10.0, lambda_gen=1.0)
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
#     As per the example above, an ``__init__()`` call to the parent class
#     must be made before assignment on the child.
#
# :ivar training: Boolean represents whether this module is in training or
#                 evaluation mode.
# :vartype training: bool

# %%
#| echo: false
#| output: asis
show_doc(real_sub_fake)
# Out:
# ---
#
# [source](https://github.com/bmandracchia/Noise2Model/blob/main/Noise2Model/loss.py#L212){target="_blank" style="float:right; font-size:smaller"}
#
# ### real_sub_fake
#
# >      real_sub_fake ()
#
# Base class for all neural network modules.
#
# Your models should also subclass this class.
#
# Modules can also contain other Modules, allowing to nest them in
# a tree structure. You can assign the submodules as regular attributes::
#
#     import torch.nn as nn
#     import torch.nn.functional as F
#
#     class Model(nn.Module):
#         def __init__(self):
#             super().__init__()
#             self.conv1 = nn.Conv2d(1, 20, 5)
#             self.conv2 = nn.Conv2d(20, 20, 5)
#
#         def forward(self, x):
#             x = F.relu(self.conv1(x))
#             return F.relu(self.conv2(x))
#
# Submodules assigned in this way will be registered, and will have their
# parameters converted too when you call :meth:`to`, etc.
#
# .. note::
#     As per the example above, an ``__init__()`` call to the parent class
#     must be made before assignment on the child.
#
# :ivar training: Boolean represents whether this module is in training or
#                 evaluation mode.
# :vartype training: bool
