# %%
from conf.default import get_cfg_defaults
from Noise2Model.trainer import get_trainer_class

# %%
device = '0'

config = get_cfg_defaults()
config.merge_from_file('../conf/NMFlowGAN_NoiseModeler2.yaml')

# %%
# intialize trainer
trainer = get_trainer_class(config.BASE.trainer)(config)
trainer.set_device(device)
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 trainer = get_trainer_class(config.BASE.trainer)(config)
#       3 trainer.set_device(device)
# ----> 4 trainer.train()
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:85, in BaseTrainer.train(self)
#      83 def train(self):
#      84     # initializing
# ---> 85     self._before_train()
#      87     # warmup
#      88     if self.epoch == 1 and self.config.TRAIN.warmup:
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:196, in BaseTrainer._before_train(self)
#     193     setup_determinism(self.config.BASE.seed)
#     195 # initialing
# --> 196 self.module = self._set_module()
#     198 # training dataset loader
#     199 self.logger.info('Prepare training dataloader...')
#
# File ~/Code/Noise2Model/Noise2Model/trainer.py:789, in NoiseFlowGANTrainer._set_module(self)
#     787     module['generator'] = get_model_class(self.config.BASE.model + "generator")(dict(), dict())
#     788 else:
# --> 789     module['generator'] = get_model_class(self.config.BASE.model+ "generator")(kwargs_gen_generator, kwargs_gen_flow)
#     791 if kwargs_critic is None:
#     792     module['critic'] = get_model_class(self.config.BASE.model + "critic")(dict())
#
# File ~/Code/Noise2Model/Noise2Model/models.py:239, in NMFlowGANGenerator.__init__(self, kwargs_unet, kwargs_flow)
#     231 def __init__(
#     232     self,
#     233     kwargs_unet,
#     234     kwargs_flow,
#     235 ):
#     236     super(NMFlowGANGenerator, self).__init__(
#     237         **kwargs_flow
#     238     )
# --> 239     self.generator = UNet(
#     240          **kwargs_unet
#     241     )
#
# NameError: name 'UNet' is not defined
